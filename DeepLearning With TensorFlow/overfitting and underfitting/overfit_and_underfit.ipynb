# %% [markdown]
# # Explore overfitting and underfitting

# %% [markdown]
# As always, the code in this example will use the `tf.keras` API, which you can learn more about in the TensorFlow [Keras guide](https://www.tensorflow.org/guide/keras).
#
# In both of the previous examples—classifying movie reviews, and predicting fuel efficiency—we saw that the accuracy of our model on the validation data would peak after training for a number of epochs, and would then start decreasing.
#
# In other words, our model would *overfit* to the training data. Learning how to deal with overfitting is important. Although it's often possible to achieve high accuracy on the *training set*, what we really want is to develop models that generalize well to a *testing data* (or data they haven't seen before).
#
# The opposite of overfitting is *underfitting*. Underfitting occurs when there is still room for improvement on the test data. This can happen for a number of reasons: If the model is not powerful enough, is over-regularized, or has simply not been trained long enough. This means the network has not learned the relevant patterns in the training data.
#
# If you train for too long though, the model will start to overfit and learn patterns from the training data that don't generalize to the test data. We need to strike a balance. Understanding how to train for an appropriate number of epochs as we'll explore below is a useful skill.
#
# To prevent overfitting, the best solution is to use more training data. A model trained on more data will naturally generalize better. When that is no longer possible, the next best solution is to use techniques like regularization. These place constraints on the quantity and type of information your model can store.  If a network can only afford to memorize a small number of patterns, the optimization process will force it to focus on the most prominent patterns, which have a better chance of generalizing well.
#
# In this notebook, we'll explore two common regularization techniques—weight regularization and dropout—and use them to improve our IMDB movie review classification notebook.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.12.0

# %% [markdown]
# ## Download the IMDB dataset
#
# Rather than using an embedding as in the previous notebook, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence  `[3, 5]` into a 10,000-dimensional vector that would be all-zeros except for indices 3 and 5, which would be ones.

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 16s 1us/step

# %% [markdown]
# Let's look at one of the resulting multi-hot vectors. The word indices are sorted by frequency, so it is expected that there are more 1-values near index zero, as we can see in this plot:

# %%
plt.plot(train_data[0])

# %% [markdown]
# ## Demonstrate overfitting
#
# The simplest way to prevent overfitting is to reduce the size of the model, i.e. the number of learnable parameters in the model (which is determined by the number of layers and the number of units per layer). In deep learning, the number of learnable parameters in a model is often referred to as the model's "capacity". Intuitively, a model with more parameters will have more "memorization capacity" and therefore will be able to easily learn a perfect dictionary-like mapping between training samples and their targets, a mapping without any generalization power, but this would be useless when making predictions on previously unseen data.
#
# Always keep this in mind: deep learning models tend to be good at fitting to the training data, but the real challenge is generalization, not fitting.
#
# On the other hand, if the network has limited memorization resources, it will not be able to learn the mapping as easily. To minimize its loss, it will have to learn compressed representations that have more predictive power. At the same time, if you make your model too small, it will have difficulty fitting to the training data. There is a balance between "too much capacity" and "not enough capacity".
#
# Unfortunately, there is no magical formula to determine the right size or architecture of your model (in terms of the number of layers, or the right size for each layer). You will have to experiment using a series of different architectures.
#
# To find an appropriate model size, it's best to start with relatively few layers and parameters, then begin increasing the size of the layers or adding new layers until you see diminishing returns on the validation loss. Let's try this on our movie review classification network.
#
# We'll create a simple model using only ```Dense``` layers as a baseline, then create smaller and larger versions, and compare them.

# %% [markdown]
# ### Create a baseline model

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 9s - loss: 0.4691 - acc: 0.8128 - binary_crossentropy: 0.4691 - val_loss: 0.3157 - val_acc: 0.8809 - val_binary_crossentropy: 0.3157
# Epoch 2/20
#  - 6s - loss: 0.2322 - acc: 0.9161 - binary_crossentropy: 0.2322 - val_loss: 0.2835 - val_acc: 0.8874 - val_binary_crossentropy: 0.2835
# Epoch 3/20
#  - 6s - loss: 0.1717 - acc: 0.9406 - binary_crossentropy: 0.1717 - val_loss: 0.2947 - val_acc: 0.8839 - val_binary_crossentropy: 0.2947
# Epoch 4/20
#  - 6s - loss: 0.1376 - acc: 0.9533 - binary_crossentropy: 0.1376 - val_loss: 0.3234 - val_acc: 0.8774 - val_binary_crossentropy: 0.3234
# Epoch 5/20
#  - 7s - loss: 0.1145 - acc: 0.9624 - binary_crossentropy: 0.1145 - val_loss: 0.3539 - val_acc: 0.8715 - val_binary_crossentropy: 0.3539
# Epoch 6/20
#  - 7s - loss: 0.0940 - acc: 0.9711 - binary_crossentropy: 0.0940 - val_loss: 0.3893 - val_acc: 0.8678 - val_binary_crossentropy: 0.3893
# Epoch 7/20
#  - 6s - loss: 0.0771 - acc: 0.9779 - binary_crossentropy: 0.0771 - val_loss: 0.4455 - val_acc: 0.8601 - val_binary_crossentropy: 0.4455
# Epoch 8/20
#  - 6s - loss: 0.0642 - acc: 0.9825 - binary_crossentropy: 0.0642 - val_loss: 0.4732 - val_acc: 0.8612 - val_binary_crossentropy: 0.4732
# Epoch 9/20
#  - 7s - loss: 0.0525 - acc: 0.9879 - binary_crossentropy: 0.0525 - val_loss: 0.5186 - val_acc: 0.8577 - val_binary_crossentropy: 0.5186
# Epoch 10/20
#  - 7s - loss: 0.0430 - acc: 0.9909 - binary_crossentropy: 0.0430 - val_loss: 0.5747 - val_acc: 0.8533 - val_binary_crossentropy: 0.5747
# Epoch 11/20
#  - 7s - loss: 0.0369 - acc: 0.9923 - binary_crossentropy: 0.0369 - val_loss: 0.6129 - val_acc: 0.8529 - val_binary_crossentropy: 0.6129
# Epoch 12/20
#  - 7s - loss: 0.0280 - acc: 0.9952 - binary_crossentropy: 0.0280 - val_loss: 0.6584 - val_acc: 0.8534 - val_binary_crossentropy: 0.6584
# Epoch 13/20
#  - 7s - loss: 0.0218 - acc: 0.9967 - binary_crossentropy: 0.0218 - val_loss: 0.7013 - val_acc: 0.8508 - val_binary_crossentropy: 0.7013
# Epoch 14/20
#  - 6s - loss: 0.0169 - acc: 0.9980 - binary_crossentropy: 0.0169 - val_loss: 0.7464 - val_acc: 0.8497 - val_binary_crossentropy: 0.7464
# Epoch 15/20
#  - 7s - loss: 0.0130 - acc: 0.9991 - binary_crossentropy: 0.0130 - val_loss: 0.7889 - val_acc: 0.8490 - val_binary_crossentropy: 0.7889
# Epoch 16/20
#  - 6s - loss: 0.0103 - acc: 0.9995 - binary_crossentropy: 0.0103 - val_loss: 0.8200 - val_acc: 0.8487 - val_binary_crossentropy: 0.8200
# Epoch 17/20
#  - 6s - loss: 0.0083 - acc: 0.9999 - binary_crossentropy: 0.0083 - val_loss: 0.8623 - val_acc: 0.8490 - val_binary_crossentropy: 0.8623
# Epoch 18/20
#  - 7s - loss: 0.0067 - acc: 0.9999 - binary_crossentropy: 0.0067 - val_loss: 0.8932 - val_acc: 0.8480 - val_binary_crossentropy: 0.8932
# Epoch 19/20
#  - 6s - loss: 0.0054 - acc: 1.0000 - binary_crossentropy: 0.0054 - val_loss: 0.9162 - val_acc: 0.8482 - val_binary_crossentropy: 0.9162
# Epoch 20/20
#  - 6s - loss: 0.0045 - acc: 1.0000 - binary_crossentropy: 0.0045 - val_loss: 0.9483 - val_acc: 0.8477 - val_binary_crossentropy: 0.9483

# %% [markdown]
# ### Create a smaller model

# %% [markdown]
# Let's create a model with less hidden units to compare against the baseline model that we just created:

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And train the model using the same data:

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.6061 - acc: 0.6796 - binary_crossentropy: 0.6061 - val_loss: 0.5307 - val_acc: 0.7920 - val_binary_crossentropy: 0.5307
# Epoch 2/20
#  - 6s - loss: 0.4719 - acc: 0.8579 - binary_crossentropy: 0.4719 - val_loss: 0.4736 - val_acc: 0.8494 - val_binary_crossentropy: 0.4736
# Epoch 3/20
#  - 5s - loss: 0.4121 - acc: 0.9060 - binary_crossentropy: 0.4121 - val_loss: 0.4427 - val_acc: 0.8732 - val_binary_crossentropy: 0.4427
# Epoch 4/20
#  - 5s - loss: 0.3677 - acc: 0.9304 - binary_crossentropy: 0.3677 - val_loss: 0.4233 - val_acc: 0.8774 - val_binary_crossentropy: 0.4233
# Epoch 5/20
#  - 6s - loss: 0.3297 - acc: 0.9446 - binary_crossentropy: 0.3297 - val_loss: 0.4061 - val_acc: 0.8812 - val_binary_crossentropy: 0.4061
# Epoch 6/20
#  - 6s - loss: 0.2951 - acc: 0.9538 - binary_crossentropy: 0.2951 - val_loss: 0.3989 - val_acc: 0.8763 - val_binary_crossentropy: 0.3989
# Epoch 7/20
#  - 6s - loss: 0.2625 - acc: 0.9625 - binary_crossentropy: 0.2625 - val_loss: 0.3919 - val_acc: 0.8753 - val_binary_crossentropy: 0.3919
# Epoch 8/20
#  - 5s - loss: 0.2329 - acc: 0.9676 - binary_crossentropy: 0.2329 - val_loss: 0.3749 - val_acc: 0.8754 - val_binary_crossentropy: 0.3749
# Epoch 9/20
#  - 6s - loss: 0.2038 - acc: 0.9721 - binary_crossentropy: 0.2038 - val_loss: 0.3721 - val_acc: 0.8735 - val_binary_crossentropy: 0.3721
# Epoch 10/20
#  - 7s - loss: 0.1744 - acc: 0.9747 - binary_crossentropy: 0.1744 - val_loss: 0.3618 - val_acc: 0.8728 - val_binary_crossentropy: 0.3618
# Epoch 11/20
#  - 6s - loss: 0.1439 - acc: 0.9768 - binary_crossentropy: 0.1439 - val_loss: 0.3551 - val_acc: 0.8710 - val_binary_crossentropy: 0.3551
# Epoch 12/20
#  - 6s - loss: 0.1174 - acc: 0.9780 - binary_crossentropy: 0.1174 - val_loss: 0.3577 - val_acc: 0.8707 - val_binary_crossentropy: 0.3577
# Epoch 13/20
#  - 6s - loss: 0.0975 - acc: 0.9805 - binary_crossentropy: 0.0975 - val_loss: 0.3725 - val_acc: 0.8690 - val_binary_crossentropy: 0.3725
# Epoch 14/20
#  - 6s - loss: 0.0824 - acc: 0.9836 - binary_crossentropy: 0.0824 - val_loss: 0.3848 - val_acc: 0.8667 - val_binary_crossentropy: 0.3848
# Epoch 15/20
#  - 7s - loss: 0.0707 - acc: 0.9856 - binary_crossentropy: 0.0707 - val_loss: 0.4070 - val_acc: 0.8666 - val_binary_crossentropy: 0.4070
# Epoch 16/20
#  - 6s - loss: 0.0615 - acc: 0.9875 - binary_crossentropy: 0.0615 - val_loss: 0.4263 - val_acc: 0.8657 - val_binary_crossentropy: 0.4263
# Epoch 17/20
#  - 8s - loss: 0.0546 - acc: 0.9890 - binary_crossentropy: 0.0546 - val_loss: 0.4460 - val_acc: 0.8649 - val_binary_crossentropy: 0.4460
# Epoch 18/20
#  - 8s - loss: 0.0486 - acc: 0.9900 - binary_crossentropy: 0.0486 - val_loss: 0.4560 - val_acc: 0.8628 - val_binary_crossentropy: 0.4560
# Epoch 19/20
#  - 6s - loss: 0.0438 - acc: 0.9908 - binary_crossentropy: 0.0438 - val_loss: 0.4767 - val_acc: 0.8628 - val_binary_crossentropy: 0.4767
# Epoch 20/20
#  - 6s - loss: 0.0401 - acc: 0.9913 - binary_crossentropy: 0.0401 - val_loss: 0.5000 - val_acc: 0.8634 - val_binary_crossentropy: 0.5000

# %% [markdown]
# ### Create a bigger model
#
# As an exercise, you can create an even larger model, and see how quickly it begins overfitting.  Next, let's add to this benchmark a network that has much more capacity, far more than the problem would warrant:

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# And, again, train the model using the same data:

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 29s - loss: 0.3437 - acc: 0.8548 - binary_crossentropy: 0.3437 - val_loss: 0.2938 - val_acc: 0.8798 - val_binary_crossentropy: 0.2938
# Epoch 2/20
#  - 28s - loss: 0.1337 - acc: 0.9513 - binary_crossentropy: 0.1337 - val_loss: 0.3606 - val_acc: 0.8611 - val_binary_crossentropy: 0.3606
# Epoch 3/20
#  - 29s - loss: 0.0408 - acc: 0.9891 - binary_crossentropy: 0.0408 - val_loss: 0.4362 - val_acc: 0.8694 - val_binary_crossentropy: 0.4362
# Epoch 4/20
#  - 27s - loss: 0.0064 - acc: 0.9991 - binary_crossentropy: 0.0064 - val_loss: 0.6024 - val_acc: 0.8692 - val_binary_crossentropy: 0.6024
# Epoch 5/20
#  - 31s - loss: 7.3414e-04 - acc: 1.0000 - binary_crossentropy: 7.3414e-04 - val_loss: 0.6809 - val_acc: 0.8710 - val_binary_crossentropy: 0.6809
# Epoch 6/20
#  - 31s - loss: 2.2753e-04 - acc: 1.0000 - binary_crossentropy: 2.2753e-04 - val_loss: 0.7167 - val_acc: 0.8712 - val_binary_crossentropy: 0.7167
# Epoch 7/20
#  - 30s - loss: 1.4308e-04 - acc: 1.0000 - binary_crossentropy: 1.4308e-04 - val_loss: 0.7414 - val_acc: 0.8712 - val_binary_crossentropy: 0.7414
# Epoch 8/20
#  - 29s - loss: 1.0385e-04 - acc: 1.0000 - binary_crossentropy: 1.0385e-04 - val_loss: 0.7597 - val_acc: 0.8710 - val_binary_crossentropy: 0.7597
# Epoch 9/20
#  - 30s - loss: 8.0118e-05 - acc: 1.0000 - binary_crossentropy: 8.0118e-05 - val_loss: 0.7751 - val_acc: 0.8716 - val_binary_crossentropy: 0.7751
# Epoch 10/20
#  - 29s - loss: 6.4129e-05 - acc: 1.0000 - binary_crossentropy: 6.4129e-05 - val_loss: 0.7878 - val_acc: 0.8718 - val_binary_crossentropy: 0.7878
# Epoch 11/20
#  - 29s - loss: 5.2803e-05 - acc: 1.0000 - binary_crossentropy: 5.2803e-05 - val_loss: 0.7992 - val_acc: 0.8718 - val_binary_crossentropy: 0.7992
# Epoch 12/20
#  - 30s - loss: 4.4233e-05 - acc: 1.0000 - binary_crossentropy: 4.4233e-05 - val_loss: 0.8091 - val_acc: 0.8716 - val_binary_crossentropy: 0.8091
# Epoch 13/20
#  - 28s - loss: 3.7692e-05 - acc: 1.0000 - binary_crossentropy: 3.7692e-05 - val_loss: 0.8178 - val_acc: 0.8717 - val_binary_crossentropy: 0.8178
# Epoch 14/20
#  - 29s - loss: 3.2523e-05 - acc: 1.0000 - binary_crossentropy: 3.2523e-05 - val_loss: 0.8261 - val_acc: 0.8716 - val_binary_crossentropy: 0.8261
# Epoch 15/20
#  - 28s - loss: 2.8324e-05 - acc: 1.0000 - binary_crossentropy: 2.8324e-05 - val_loss: 0.8338 - val_acc: 0.8716 - val_binary_crossentropy: 0.8338
# Epoch 16/20
#  - 29s - loss: 2.4913e-05 - acc: 1.0000 - binary_crossentropy: 2.4913e-05 - val_loss: 0.8403 - val_acc: 0.8714 - val_binary_crossentropy: 0.8403
# Epoch 17/20
#  - 29s - loss: 2.2074e-05 - acc: 1.0000 - binary_crossentropy: 2.2074e-05 - val_loss: 0.8479 - val_acc: 0.8718 - val_binary_crossentropy: 0.8479
# Epoch 18/20
#  - 28s - loss: 1.9716e-05 - acc: 1.0000 - binary_crossentropy: 1.9716e-05 - val_loss: 0.8537 - val_acc: 0.8714 - val_binary_crossentropy: 0.8537
# Epoch 19/20
#  - 28s - loss: 1.7664e-05 - acc: 1.0000 - binary_crossentropy: 1.7664e-05 - val_loss: 0.8593 - val_acc: 0.8713 - val_binary_crossentropy: 0.8593
# Epoch 20/20
#  - 28s - loss: 1.5942e-05 - acc: 1.0000 - binary_crossentropy: 1.5942e-05 - val_loss: 0.8653 - val_acc: 0.8716 - val_binary_crossentropy: 0.8653

# %% [markdown]
# ### Plot the training and validation loss
#
# <!--TODO(markdaoust): This should be a one-liner with tensorboard -->

# %% [markdown]
# The solid lines show the training loss, and the dashed lines show the validation loss (remember: a lower validation loss indicates a better model). Here, the smaller network begins overfitting later than the baseline model (after 6 epochs rather than 4) and its performance degrades much more slowly once it starts overfitting.

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# Notice that the larger network begins overfitting almost right away, after just one epoch, and overfits much more severely. The more capacity the network has, the quicker it will be able to model the training data (resulting in a low training loss), but the more susceptible it is to overfitting (resulting in a large difference between the training and validation loss).

# %% [markdown]
# ## Strategies

# %% [markdown]
# ### Add weight regularization

# %% [markdown]
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# * [L1 regularization](https://developers.google.com/machine-learning/glossary/#L1_regularization), where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# * [L2 regularization](https://developers.google.com/machine-learning/glossary/#L2_regularization), where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 7s - loss: 0.5178 - acc: 0.8103 - binary_crossentropy: 0.4753 - val_loss: 0.3764 - val_acc: 0.8773 - val_binary_crossentropy: 0.3307
# Epoch 2/20
#  - 6s - loss: 0.3022 - acc: 0.9093 - binary_crossentropy: 0.2519 - val_loss: 0.3420 - val_acc: 0.8840 - val_binary_crossentropy: 0.2885
# Epoch 3/20
#  - 7s - loss: 0.2562 - acc: 0.9294 - binary_crossentropy: 0.2002 - val_loss: 0.3436 - val_acc: 0.8848 - val_binary_crossentropy: 0.2856
# Epoch 4/20
#  - 6s - loss: 0.2310 - acc: 0.9409 - binary_crossentropy: 0.1716 - val_loss: 0.3558 - val_acc: 0.8824 - val_binary_crossentropy: 0.2955
# Epoch 5/20
#  - 6s - loss: 0.2177 - acc: 0.9462 - binary_crossentropy: 0.1560 - val_loss: 0.3698 - val_acc: 0.8787 - val_binary_crossentropy: 0.3073
# Epoch 6/20
#  - 8s - loss: 0.2077 - acc: 0.9519 - binary_crossentropy: 0.1445 - val_loss: 0.3916 - val_acc: 0.8732 - val_binary_crossentropy: 0.3278
# Epoch 7/20
#  - 7s - loss: 0.1997 - acc: 0.9546 - binary_crossentropy: 0.1351 - val_loss: 0.3984 - val_acc: 0.8740 - val_binary_crossentropy: 0.3334
# Epoch 8/20
#  - 6s - loss: 0.1944 - acc: 0.9562 - binary_crossentropy: 0.1288 - val_loss: 0.4118 - val_acc: 0.8714 - val_binary_crossentropy: 0.3459
# Epoch 9/20
#  - 8s - loss: 0.1899 - acc: 0.9572 - binary_crossentropy: 0.1234 - val_loss: 0.4343 - val_acc: 0.8648 - val_binary_crossentropy: 0.3675
# Epoch 10/20
#  - 7s - loss: 0.1851 - acc: 0.9596 - binary_crossentropy: 0.1178 - val_loss: 0.4379 - val_acc: 0.8656 - val_binary_crossentropy: 0.3703
# Epoch 11/20
#  - 7s - loss: 0.1814 - acc: 0.9617 - binary_crossentropy: 0.1133 - val_loss: 0.4629 - val_acc: 0.8641 - val_binary_crossentropy: 0.3944
# Epoch 12/20
#  - 6s - loss: 0.1789 - acc: 0.9623 - binary_crossentropy: 0.1100 - val_loss: 0.4597 - val_acc: 0.8646 - val_binary_crossentropy: 0.3907
# Epoch 13/20
#  - 6s - loss: 0.1733 - acc: 0.9654 - binary_crossentropy: 0.1042 - val_loss: 0.4717 - val_acc: 0.8620 - val_binary_crossentropy: 0.4024
# Epoch 14/20
#  - 7s - loss: 0.1700 - acc: 0.9658 - binary_crossentropy: 0.1008 - val_loss: 0.4840 - val_acc: 0.8599 - val_binary_crossentropy: 0.4146
# Epoch 15/20
#  - 10s - loss: 0.1683 - acc: 0.9656 - binary_crossentropy: 0.0988 - val_loss: 0.4939 - val_acc: 0.8609 - val_binary_crossentropy: 0.4241
# Epoch 16/20
#  - 7s - loss: 0.1674 - acc: 0.9663 - binary_crossentropy: 0.0970 - val_loss: 0.5106 - val_acc: 0.8594 - val_binary_crossentropy: 0.4398
# Epoch 17/20
#  - 6s - loss: 0.1658 - acc: 0.9674 - binary_crossentropy: 0.0945 - val_loss: 0.5150 - val_acc: 0.8576 - val_binary_crossentropy: 0.4435
# Epoch 18/20
#  - 7s - loss: 0.1624 - acc: 0.9684 - binary_crossentropy: 0.0912 - val_loss: 0.5256 - val_acc: 0.8541 - val_binary_crossentropy: 0.4543
# Epoch 19/20
#  - 7s - loss: 0.1607 - acc: 0.9691 - binary_crossentropy: 0.0891 - val_loss: 0.5489 - val_acc: 0.8538 - val_binary_crossentropy: 0.4772
# Epoch 20/20
#  - 7s - loss: 0.1571 - acc: 0.9704 - binary_crossentropy: 0.0853 - val_loss: 0.5471 - val_acc: 0.8559 - val_binary_crossentropy: 0.4751

# %% [markdown]
# ```l2(0.001)``` means that every coefficient in the weight matrix of the layer will add ```0.001 * weight_coefficient_value**2``` to the total loss of the network. Note that because this penalty is only added at training time, the loss for this network will be much higher at training than at test time.
#
# Here's the impact of our L2 regularization penalty:

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# As you can see, the L2 regularized model has become much more resistant to overfitting than the baseline model, even though both models have the same number of parameters.

# %% [markdown]
# ### Add dropout
#
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5,
# 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 7s - loss: 0.6086 - acc: 0.6658 - binary_crossentropy: 0.6086 - val_loss: 0.4681 - val_acc: 0.8545 - val_binary_crossentropy: 0.4681
# Epoch 2/20
#  - 7s - loss: 0.4444 - acc: 0.8097 - binary_crossentropy: 0.4444 - val_loss: 0.3346 - val_acc: 0.8813 - val_binary_crossentropy: 0.3346
# Epoch 3/20
#  - 6s - loss: 0.3450 - acc: 0.8696 - binary_crossentropy: 0.3450 - val_loss: 0.2858 - val_acc: 0.8875 - val_binary_crossentropy: 0.2858
# Epoch 4/20
#  - 6s - loss: 0.2844 - acc: 0.8983 - binary_crossentropy: 0.2844 - val_loss: 0.2735 - val_acc: 0.8885 - val_binary_crossentropy: 0.2735
# Epoch 5/20
#  - 6s - loss: 0.2437 - acc: 0.9162 - binary_crossentropy: 0.2437 - val_loss: 0.2773 - val_acc: 0.8876 - val_binary_crossentropy: 0.2773
# Epoch 6/20
#  - 6s - loss: 0.2130 - acc: 0.9265 - binary_crossentropy: 0.2130 - val_loss: 0.2904 - val_acc: 0.8860 - val_binary_crossentropy: 0.2904
# Epoch 7/20
#  - 6s - loss: 0.1869 - acc: 0.9367 - binary_crossentropy: 0.1869 - val_loss: 0.3034 - val_acc: 0.8849 - val_binary_crossentropy: 0.3034
# Epoch 8/20
#  - 6s - loss: 0.1657 - acc: 0.9454 - binary_crossentropy: 0.1657 - val_loss: 0.3258 - val_acc: 0.8834 - val_binary_crossentropy: 0.3258
# Epoch 9/20
#  - 7s - loss: 0.1470 - acc: 0.9507 - binary_crossentropy: 0.1470 - val_loss: 0.3367 - val_acc: 0.8826 - val_binary_crossentropy: 0.3367
# Epoch 10/20
#  - 6s - loss: 0.1298 - acc: 0.9559 - binary_crossentropy: 0.1298 - val_loss: 0.3594 - val_acc: 0.8815 - val_binary_crossentropy: 0.3594
# Epoch 11/20
#  - 7s - loss: 0.1228 - acc: 0.9578 - binary_crossentropy: 0.1228 - val_loss: 0.3738 - val_acc: 0.8793 - val_binary_crossentropy: 0.3738
# Epoch 12/20
#  - 6s - loss: 0.1109 - acc: 0.9607 - binary_crossentropy: 0.1109 - val_loss: 0.4099 - val_acc: 0.8806 - val_binary_crossentropy: 0.4099
# Epoch 13/20
#  - 7s - loss: 0.0995 - acc: 0.9652 - binary_crossentropy: 0.0995 - val_loss: 0.4460 - val_acc: 0.8777 - val_binary_crossentropy: 0.4460
# Epoch 14/20
#  - 6s - loss: 0.0941 - acc: 0.9669 - binary_crossentropy: 0.0941 - val_loss: 0.4565 - val_acc: 0.8783 - val_binary_crossentropy: 0.4565
# Epoch 15/20
#  - 6s - loss: 0.0872 - acc: 0.9679 - binary_crossentropy: 0.0872 - val_loss: 0.4818 - val_acc: 0.8769 - val_binary_crossentropy: 0.4818
# Epoch 16/20
#  - 7s - loss: 0.0815 - acc: 0.9699 - binary_crossentropy: 0.0815 - val_loss: 0.5202 - val_acc: 0.8769 - val_binary_crossentropy: 0.5202
# Epoch 17/20
#  - 6s - loss: 0.0801 - acc: 0.9691 - binary_crossentropy: 0.0801 - val_loss: 0.5324 - val_acc: 0.8773 - val_binary_crossentropy: 0.5324
# Epoch 18/20
#  - 6s - loss: 0.0750 - acc: 0.9718 - binary_crossentropy: 0.0750 - val_loss: 0.5344 - val_acc: 0.8776 - val_binary_crossentropy: 0.5344
# Epoch 19/20
#  - 6s - loss: 0.0726 - acc: 0.9720 - binary_crossentropy: 0.0726 - val_loss: 0.5572 - val_acc: 0.8760 - val_binary_crossentropy: 0.5572
# Epoch 20/20
#  - 6s - loss: 0.0723 - acc: 0.9722 - binary_crossentropy: 0.0723 - val_loss: 0.5651 - val_acc: 0.8757 - val_binary_crossentropy: 0.5651

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
#
#
# To recap: here the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# And two important approaches not covered in this guide are data-augmentation and batch normalization.
