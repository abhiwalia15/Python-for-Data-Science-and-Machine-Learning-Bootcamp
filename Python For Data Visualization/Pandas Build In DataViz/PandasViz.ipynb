# %%
import numpy as np

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv ('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %% [markdown]
# ##

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist()

# %%
df1['A'].hist(bins=30, color='pink')

# %%
import seaborn as sns

sns.set_style('whitegrid')

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df1['A'].plot(kind='hist', bins=30)

# %%
df1['B'].plot.hist()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.5642)

# %%
df2.plot.area(color='black', alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.line(x='A',y='B',figsize=(12,3),lw=1)

# %%
df1.plot.scatter(x='A', y='B')

# %%
df1.plot.scatter(x='A', y='B', c="C")

# %%
df1.plot.scatter(x='A', y='B', c="C", cmap='rainbow')

# %%
df1.plot.scatter(x='A', y='B', s=df1['C'])
# Out:
# c:\python 3.6.5\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*100)
# Out:
# c:\python 3.6.5\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box(color='black')

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df
# Out:
#             a         b
# 0    0.751454  0.093778
# 1    0.035864 -1.273127
# 2    1.633882  0.913748
# 3    0.227771  0.006537
# 4    2.042257 -2.318568
# 5    0.287384  0.319503
# 6   -1.303144  0.231328
# 7    0.129655  0.094018
# 8   -0.029847  0.056845
# 9   -1.139620  0.605811
# 10   0.367950 -1.377999
# 11   1.136069 -0.314414
# 12  -1.729479 -0.281316
# 13  -0.038079 -1.384440
# 14  -0.358666 -0.036700
# 15   0.484793 -1.109071
# 16   1.072831  1.282259
# 17   0.241697  1.863914
# 18   0.366134 -0.178626
# 19   1.375135 -0.290427
# 20  -0.825695  1.092103
# 21   0.245596 -1.468097
# 22  -0.136393  0.146550
# 23  -3.942159  0.399743
# 24   0.375748  1.653676
# 25   1.306045  0.065576
# 26   1.562100  0.649552
# 27   0.758550 -0.760599
# 28  -0.583225  0.059530
# 29  -0.618667 -2.330973
# ..        ...       ...
# 970 -0.049097 -1.381387
# 971  1.923533  0.713006
# 972 -0.699509  0.013337
# 973 -0.911363  0.092262
# 974  1.281451 -1.821877
# 975 -0.992035 -0.284294
# ...

# %%
df.head()
# Out:
#           a         b
# 0  0.751454  0.093778
# 1  0.035864 -1.273127
# 2  1.633882  0.913748
# 3  0.227771  0.006537
# 4  2.042257 -2.318568

# %%
df.plot.hexbin(x='a',y='b')

# %%
df.plot.hexbin(x='a',y='b', gridsize=25, cmap='rainbow')

# %%
df.plot.hexbin(x='a', y='b', gridsize=15, color='green', cmap='coolwarm' )
# Out:
# c:\python 3.6.5\lib\site-packages\pandas\plotting\_core.py:211: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   warnings.warn("'color' and 'colormap' cannot be used "

# %%
df2['a'].plot.kde()

# %%
df.plot.kde()

# %%
df.plot.density()

# %%
df.plot.area(stacked=False)
