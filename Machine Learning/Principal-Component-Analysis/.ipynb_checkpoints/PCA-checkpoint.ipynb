# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
type(cancer)
# Out:
# sklearn.utils.Bunch

# %%
cancer.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
#print(cancer['DESCR'])

# %%
df = pd.DataFrame(cancer['data'], columns=cancer['feature_names'])

# %%
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
# mean radius                569 non-null float64
# mean texture               569 non-null float64
# mean perimeter             569 non-null float64
# mean area                  569 non-null float64
# mean smoothness            569 non-null float64
# mean compactness           569 non-null float64
# mean concavity             569 non-null float64
# mean concave points        569 non-null float64
# mean symmetry              569 non-null float64
# mean fractal dimension     569 non-null float64
# radius error               569 non-null float64
# texture error              569 non-null float64
# perimeter error            569 non-null float64
# area error                 569 non-null float64
# smoothness error           569 non-null float64
# compactness error          569 non-null float64
# concavity error            569 non-null float64
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# # standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_data = scaler.transform(df)

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
#convert 30 dimensional dataset into 3 components
pca = PCA(n_components=3)

# %%
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(scaled_data)

# %% [markdown]
# ### we just transformed our data

# %%
scaled_data.shape
# Out:
# (569, 30)

# %%
x_pca.shape
# Out:
# (569, 3)

# %% [markdown]
# ## plotting

# %%
#plotting first PCA axis VS second PCA axis
plt.figure(figsize=(10,6))
plt.scatter(x_pca[:,0], x_pca[:,1], c=cancer['target'], cmap='coolwarm',
            edgecolors='yellow')

plt.xlabel('first principal components')
plt.ylabel('second principal components')
# Out:
# Text(0,0.5,'second principal components')

# %%
#plotting second PCA axis VS third PCA axis
plt.figure(figsize=(10,6))
plt.scatter(x_pca[:,1], x_pca[:,2], c=cancer['target'], cmap='coolwarm',
            edgecolors='yellow')

plt.xlabel('second principal components')
plt.ylabel('third principal components')
# Out:
# Text(0,0.5,'third principal components')

# %% [markdown]
# # Interpreting the components

# %% [markdown]
# The components correspond to combinations of the original features, the components themselves are stored as an attribute of the fitted PCA object:###

# %%
pca.components_
# Out:
# array([[ 0.21890244,  0.10372458,  0.22753729,  0.22099499,  0.14258969,
#          0.23928535,  0.25840048,  0.26085376,  0.13816696,  0.06436335,
#          0.20597878,  0.01742803,  0.21132592,  0.20286964,  0.01453145,
#          0.17039345,  0.15358979,  0.1834174 ,  0.04249842,  0.10256832,
#          0.22799663,  0.10446933,  0.23663968,  0.22487053,  0.12795256,
#          0.21009588,  0.22876753,  0.25088597,  0.12290456,  0.13178394],
#        [-0.23385713, -0.05970609, -0.21518136, -0.23107671,  0.18611301,
#          0.15189161,  0.06016537, -0.03476749,  0.19034877,  0.36657548,
#         -0.10555215,  0.08997968, -0.08945723, -0.15229263,  0.20443046,
#          0.23271588,  0.19720728,  0.13032157,  0.183848  ,  0.28009202,
#         -0.21986638, -0.0454673 , -0.19987843, -0.21935186,  0.17230435,
#          0.14359317,  0.09796411, -0.00825723,  0.14188335,  0.27533947],
#        [-0.00853124,  0.06454987, -0.00931422,  0.02869953, -0.10429175,
# ...

# %%
df_comp = pd.DataFrame(pca.components_, columns=cancer['feature_names'])

# %%
df_comp.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.218902      0.103725        0.227537   0.220995         0.142590
# 1    -0.233857     -0.059706       -0.215181  -0.231077         0.186113
# 2    -0.008531      0.064550       -0.009314   0.028700        -0.104292
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.239285        0.258400             0.260854       0.138167
# 1          0.151892        0.060165            -0.034767       0.190349
# 2         -0.074092        0.002734            -0.025564      -0.040240
#
#    mean fractal dimension           ...             worst radius  \
# 0                0.064363           ...                 0.227997
# 1                0.366575           ...                -0.219866
# 2               -0.022574           ...                -0.047507
#
#    worst texture  worst perimeter  worst area  worst smoothness  \
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_comp.corr(), cmap='plasma')

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_comp, cmap='plasma')
