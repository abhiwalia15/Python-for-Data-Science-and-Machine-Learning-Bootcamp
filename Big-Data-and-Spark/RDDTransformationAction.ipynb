# %%
# %%writefile example2.txt
# first
# second line
# the third line
# then a fourth line
# Out:
# Writing example2.txt

# %%
from pyspark import SparkContext

# %%
sc = SparkContext()

# %%
sc.textFile('example2.txt')
# Out:
# example2.txt MapPartitionsRDD[3] at textFile at NativeMethodAccessorImpl.java:0

# %%
text_rdd = sc.textFile('example2.txt')

# %%
words = text_rdd.map(lambda line: line.split())

# %%
words.collect()
# Out:
# [['first'],
#  ['second', 'line'],
#  ['the', 'third', 'line'],
#  ['then', 'a', 'fourth', 'line']]

# %%
text_rdd.collect()
# Out:
# ['first ', 'second line', 'the third line', 'then a fourth line']

# %%
text_rdd.flatMap(lambda line: line.split()).collect()
# Out:
# ['first',
#  'second',
#  'line',
#  'the',
#  'third',
#  'line',
#  'then',
#  'a',
#  'fourth',
#  'line']

# %% [markdown]
# ## RDD and Key values pair

# %%
# %%writefile services.txt
# #EventId    Timestamp    Customer   State    ServiceID    Amount
# 201       10/13/2017      100       NY       131          100.00
# 204       10/18/2017      700       TX       129          450.00
# 202       10/15/2017      203       CA       121          200.00
# 206       10/19/2017      202       CA       131          500.00
# 203       10/17/2017      101       NY       173          750.00
# 205       10/19/2017      202       TX       121          200.00
# Out:
# Writing services.txt

# %%
services = sc.textFile('services.txt')

# %%
services.take(2)
# Out:
# ['#EventId    Timestamp    Customer   State    ServiceID    Amount',
#  '201       10/13/2017      100       NY       131          100.00']

# %%
services.top(2)
# Out:
# ['206       10/19/2017      202       CA       131          500.00',
#  '205       10/19/2017      202       TX       121          200.00']

# %%
services.map(lambda line: line.split()).take(3)
# Out:
# [['#EventId', 'Timestamp', 'Customer', 'State', 'ServiceID', 'Amount'],
#  ['201', '10/13/2017', '100', 'NY', '131', '100.00'],
#  ['204', '10/18/2017', '700', 'TX', '129', '450.00']]

# %%
clean = services.map(lambda x: x[1:] if x[0]=='#' else x).map(lambda x: x.split())

# %%
clean
# Out:
# [['EventId', 'Timestamp', 'Customer', 'State', 'ServiceID', 'Amount'],
#  ['201', '10/13/2017', '100', 'NY', '131', '100.00'],
#  ['204', '10/18/2017', '700', 'TX', '129', '450.00'],
#  ['202', '10/15/2017', '203', 'CA', '121', '200.00'],
#  ['206', '10/19/2017', '202', 'CA', '131', '500.00'],
#  ['203', '10/17/2017', '101', 'NY', '173', '750.00'],
#  ['205', '10/19/2017', '202', 'TX', '121', '200.00']]

# %% [markdown]
# ## Using Key Value Pairs for Operations

# %%
# From Previous
cleanServ = services.map(lambda x: x[1:] if x[0]=='#' else x).map(lambda x: x.split())

# %%
pairs = cleanServ.map(lambda lst: (lst[3], lst[-1])).collect()

# %%
# Continue with reduceByKey
# Notice how it assumes that the first item is the key!
cleanServ.map(lambda lst: (lst[3],lst[-1]))\
         .reduceByKey(lambda amt1,amt2 : amt1+amt2)\
         .collect()
# Out:
# [('State', 'Amount'),
#  ('NY', '100.00750.00'),
#  ('TX', '450.00200.00'),
#  ('CA', '200.00500.00')]

# %%
# Continue with reduceByKey
# Notice how it assumes that the first item is the key!
cleanServ.map(lambda lst: (lst[3],lst[-1]))\
         .reduceByKey(lambda amt1,amt2 : float(amt1)+float(amt2))\
         .collect()
# Out:
# [('State', 'Amount'), ('NY', 850.0), ('TX', 650.0), ('CA', 700.0)]

# %%
clean
# Out:
# [['EventId', 'Timestamp', 'Customer', 'State', 'ServiceID', 'Amount'],
#  ['201', '10/13/2017', '100', 'NY', '131', '100.00'],
#  ['204', '10/18/2017', '700', 'TX', '129', '450.00'],
#  ['202', '10/15/2017', '203', 'CA', '121', '200.00'],
#  ['206', '10/19/2017', '202', 'CA', '131', '500.00'],
#  ['203', '10/17/2017', '101', 'NY', '173', '750.00'],
#  ['205', '10/19/2017', '202', 'TX', '121', '200.00']]

# %%
# Grab state and amounts
# Add them
# Get rid of ('State','Amount')
# Sort them by the amount value
cleanServ.map(lambda lst: (lst[3],lst[-1]))\
.reduceByKey(lambda amt1,amt2 : float(amt1)+float(amt2))\
.filter(lambda x: not x[0]=='State')\
.sortBy(lambda stateAmount: stateAmount[1], ascending=False)\
.collect()
# Out:
# [('NY', 850.0), ('CA', 700.0), ('TX', 650.0)]

# %%
x = ['ID','States','Amount']

# %%
def func1(lst):
    return lst[-1]

# %%
def func2(id_st_amt):
    #unpack values
    (id,st,amt) = id_st_amt
    return amt

# %%
func1(x)
# Out:
# 'Amount'

# %%
func2(x)
# Out:
# 'Amount'
